# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
 #Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
len(lats)
# Out:
# 2000

# %%
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
from citipy import citipy

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 734

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | nanortalik
# Processing Record 2 of Set 1 | birjand
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | muborak
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | andra
# Processing Record 9 of Set 1 | powell
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | nome
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | tutoia
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | kununurra
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | forssa
# Processing Record 25 of Set 1 | darapidap
# Processing Record 26 of Set 1 | tiarei
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | marsh harbour
# Processing Record 29 of Set 1 | ilulissat
# Processing Record 30 of Set 1 | kavaratti
# Processing Record 31 of Set 1 | sao joao da barra
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | peleduy
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | sayyan
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | sistranda
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | narsaq
# Processing Record 47 of Set 1 | road town
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | olafsvik
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | tessalit
# Processing Record 3 of Set 2 | cap-aux-meules
# Processing Record 4 of Set 2 | goure
# Processing Record 5 of Set 2 | novyy urengoy
# Processing Record 6 of Set 2 | ulladulla
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | zhongshan
# Processing Record 9 of Set 2 | farafangana
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | jarjis
# City not found. Skipping...
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | asyut
# Processing Record 20 of Set 2 | haines junction
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 23 of Set 2 | xiaolingwei
# Processing Record 24 of Set 2 | san luis
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | aklavik
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | coquimbo
# Processing Record 29 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | nouadhibou
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | komsomolskiy
# Processing Record 34 of Set 2 | peterhead
# Processing Record 35 of Set 2 | novoagansk
# Processing Record 36 of Set 2 | ilhabela
# Processing Record 37 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | praia da vitoria
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | asau
# Processing Record 42 of Set 2 | matara
# Processing Record 43 of Set 2 | kamaishi
# Processing Record 44 of Set 2 | nanpiao
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 2 | matagami
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 3 | sulangan
# Processing Record 4 of Set 3 | el sauzal
# Processing Record 5 of Set 3 | kudahuvadhoo
# Processing Record 6 of Set 3 | rio gallegos
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | koszalin
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | haga
# Processing Record 12 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 3 | andrid
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | skerries
# Processing Record 16 of Set 3 | aleppo
# Processing Record 17 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 3 | beberibe
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 3 | touros
# Processing Record 22 of Set 3 | andenes
# Processing Record 23 of Set 3 | pevek
# Processing Record 24 of Set 3 | bathsheba
# Processing Record 25 of Set 3 | newport
# Processing Record 26 of Set 3 | changji
# Processing Record 27 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | labuhan
# Processing Record 31 of Set 3 | alta floresta
# Processing Record 32 of Set 3 | henties bay
# Processing Record 33 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 3 | isangel
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 3 | imbituba
# Processing Record 38 of Set 3 | ahipara
# Processing Record 39 of Set 3 | kargasok
# Processing Record 40 of Set 3 | oussouye
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | varena
# Processing Record 43 of Set 3 | lyubech
# Processing Record 44 of Set 3 | roebourne
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | vestmannaeyjar
# Processing Record 48 of Set 3 | sitka
# Processing Record 49 of Set 3 | bethel
# Processing Record 50 of Set 3 | orcopampa
# Processing Record 1 of Set 4 | bubaque
# Processing Record 2 of Set 4 | boa vista
# Processing Record 3 of Set 4 | ballina
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | palaikastron
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | lyuban
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | narimanov
# Processing Record 10 of Set 4 | astana
# Processing Record 11 of Set 4 | phenix city
# Processing Record 12 of Set 4 | salinas
# Processing Record 13 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 4 | tiznit
# Processing Record 15 of Set 4 | willowmore
# Processing Record 16 of Set 4 | xinpu
# Processing Record 17 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 4 | port hawkesbury
# Processing Record 19 of Set 4 | markivka
# Processing Record 20 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 4 | kaitangata
# Processing Record 22 of Set 4 | tezu
# Processing Record 23 of Set 4 | jining
# Processing Record 24 of Set 4 | kampong thum
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | kovrov
# Processing Record 27 of Set 4 | eyl
# Processing Record 28 of Set 4 | east london
# Processing Record 29 of Set 4 | mariestad
# Processing Record 30 of Set 4 | tarata
# Processing Record 31 of Set 4 | lerwick
# Processing Record 32 of Set 4 | pacific grove
# Processing Record 33 of Set 4 | manicore
# Processing Record 34 of Set 4 | daan
# Processing Record 35 of Set 4 | ponta do sol
# Processing Record 36 of Set 4 | carnarvon
# Processing Record 37 of Set 4 | muzhi
# Processing Record 38 of Set 4 | saldanha
# Processing Record 39 of Set 4 | putnok
# Processing Record 40 of Set 4 | presidencia roque saenz pena
# Processing Record 41 of Set 4 | milingimbi
# City not found. Skipping...
# Processing Record 42 of Set 4 | daitari
# Processing Record 43 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 4 | ketchikan
# Processing Record 45 of Set 4 | uspenskoye
# Processing Record 46 of Set 4 | djibo
# Processing Record 47 of Set 4 | dickinson
# Processing Record 48 of Set 4 | la ronge
# Processing Record 49 of Set 4 | pokaran
# Processing Record 50 of Set 4 | rucheng
# Processing Record 1 of Set 5 | takapau
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | kodiak
# Processing Record 4 of Set 5 | georgetown
# Processing Record 5 of Set 5 | khanpur
# Processing Record 6 of Set 5 | tautira
# Processing Record 7 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 5 | praya
# Processing Record 9 of Set 5 | severo-yeniseyskiy
# Processing Record 10 of Set 5 | san policarpo
# Processing Record 11 of Set 5 | port hardy
# Processing Record 12 of Set 5 | phibun mangsahan
# Processing Record 13 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 5 | cobija
# Processing Record 15 of Set 5 | harper
# Processing Record 16 of Set 5 | gobabis
# Processing Record 17 of Set 5 | flinders
# Processing Record 18 of Set 5 | sola
# Processing Record 19 of Set 5 | mount gambier
# Processing Record 20 of Set 5 | tasiilaq
# Processing Record 21 of Set 5 | bonavista
# Processing Record 22 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | chernyshevskiy
# Processing Record 25 of Set 5 | sangar
# Processing Record 26 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 5 | port elizabeth
# Processing Record 28 of Set 5 | yerbogachen
# Processing Record 29 of Set 5 | saint-pierre
# Processing Record 30 of Set 5 | cabildo
# Processing Record 31 of Set 5 | itarema
# Processing Record 32 of Set 5 | urumqi
# Processing Record 33 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 5 | liaoyang
# Processing Record 35 of Set 5 | bardiyah
# Processing Record 36 of Set 5 | jalu
# Processing Record 37 of Set 5 | sao filipe
# Processing Record 38 of Set 5 | bredasdorp
# Processing Record 39 of Set 5 | roald
# Processing Record 40 of Set 5 | toamasina
# Processing Record 41 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | shakawe
# Processing Record 44 of Set 5 | severo-kurilsk
# Processing Record 45 of Set 5 | samarai
# Processing Record 46 of Set 5 | inhambane
# Processing Record 47 of Set 5 | akdagmadeni
# Processing Record 48 of Set 5 | aksu
# Processing Record 49 of Set 5 | necochea
# Processing Record 50 of Set 5 | qaanaaq
# Processing Record 1 of Set 6 | angra
# City not found. Skipping...
# Processing Record 2 of Set 6 | victoria
# Processing Record 3 of Set 6 | zharkent
# Processing Record 4 of Set 6 | rocha
# Processing Record 5 of Set 6 | moron
# Processing Record 6 of Set 6 | dubovskoye
# Processing Record 7 of Set 6 | manokwari
# Processing Record 8 of Set 6 | lazaro cardenas
# Processing Record 9 of Set 6 | lata
# Processing Record 10 of Set 6 | marawi
# Processing Record 11 of Set 6 | vangaindrano
# Processing Record 12 of Set 6 | zaozerne
# Processing Record 13 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 6 | rio pardo
# Processing Record 15 of Set 6 | kloulklubed
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | cherskiy
# Processing Record 18 of Set 6 | sabang
# Processing Record 19 of Set 6 | pemangkat
# Processing Record 20 of Set 6 | sultanpur
# Processing Record 21 of Set 6 | puerto del rosario
# Processing Record 22 of Set 6 | nago
# Processing Record 23 of Set 6 | jhalu
# Processing Record 24 of Set 6 | aksarka
# Processing Record 25 of Set 6 | hamilton
# Processing Record 26 of Set 6 | lompoc
# Processing Record 27 of Set 6 | marzuq
# Processing Record 28 of Set 6 | evensk
# Processing Record 29 of Set 6 | nambucca heads
# Processing Record 30 of Set 6 | seoul
# Processing Record 31 of Set 6 | ranong
# Processing Record 32 of Set 6 | meadow lake
# Processing Record 33 of Set 6 | cockburn town
# Processing Record 34 of Set 6 | verkhnyaya inta
# Processing Record 35 of Set 6 | kirakira
# Processing Record 36 of Set 6 | banska stiavnica
# Processing Record 37 of Set 6 | tuy hoa
# Processing Record 38 of Set 6 | luanda
# Processing Record 39 of Set 6 | luderitz
# Processing Record 40 of Set 6 | saint-augustin
# Processing Record 41 of Set 6 | banjar
# Processing Record 42 of Set 6 | nimes
# Processing Record 43 of Set 6 | cidreira
# Processing Record 44 of Set 6 | suntar
# Processing Record 45 of Set 6 | drayton valley
# Processing Record 46 of Set 6 | odessa
# Processing Record 47 of Set 6 | arraial do cabo
# Processing Record 48 of Set 6 | nicoya
# Processing Record 49 of Set 6 | lamar
# Processing Record 50 of Set 6 | dikson
# Processing Record 1 of Set 7 | biak
# Processing Record 2 of Set 7 | petrovsk-zabaykalskiy
# Processing Record 3 of Set 7 | sioux lookout
# Processing Record 4 of Set 7 | thinadhoo
# Processing Record 5 of Set 7 | srednekolymsk
# Processing Record 6 of Set 7 | faratsiho
# Processing Record 7 of Set 7 | hami
# Processing Record 8 of Set 7 | namibe
# Processing Record 9 of Set 7 | marathon
# Processing Record 10 of Set 7 | katobu
# Processing Record 11 of Set 7 | ambunti
# Processing Record 12 of Set 7 | treinta y tres
# Processing Record 13 of Set 7 | gogrial
# Processing Record 14 of Set 7 | fortuna
# Processing Record 15 of Set 7 | ubinskoye
# Processing Record 16 of Set 7 | libertad
# Processing Record 17 of Set 7 | tlacotepec
# Processing Record 18 of Set 7 | solhan
# Processing Record 19 of Set 7 | shestakovo
# Processing Record 20 of Set 7 | garowe
# Processing Record 21 of Set 7 | nhulunbuy
# Processing Record 22 of Set 7 | tigil
# Processing Record 23 of Set 7 | tocopilla
# Processing Record 24 of Set 7 | barcelos
# Processing Record 25 of Set 7 | bigaan
# Processing Record 26 of Set 7 | sharjah
# Processing Record 27 of Set 7 | belmonte
# Processing Record 28 of Set 7 | disraeli
# Processing Record 29 of Set 7 | ivankiv
# Processing Record 30 of Set 7 | bilma
# Processing Record 31 of Set 7 | marystown
# Processing Record 32 of Set 7 | vao
# Processing Record 33 of Set 7 | dolores
# Processing Record 34 of Set 7 | nyurba
# Processing Record 35 of Set 7 | hihya
# Processing Record 36 of Set 7 | pangnirtung
# Processing Record 37 of Set 7 | yushala
# Processing Record 38 of Set 7 | vardo
# Processing Record 39 of Set 7 | kemijarvi
# Processing Record 40 of Set 7 | kasaragod
# Processing Record 41 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 43 of Set 7 | ginir
# Processing Record 44 of Set 7 | susangerd
# Processing Record 45 of Set 7 | maun
# Processing Record 46 of Set 7 | san patricio
# Processing Record 47 of Set 7 | jucas
# Processing Record 48 of Set 7 | goderich
# Processing Record 49 of Set 7 | burica
# City not found. Skipping...
# Processing Record 50 of Set 7 | portland
# Processing Record 1 of Set 8 | phangnga
# Processing Record 2 of Set 8 | geraldton
# Processing Record 3 of Set 8 | tanout
# Processing Record 4 of Set 8 | port-gentil
# Processing Record 5 of Set 8 | ayorou
# Processing Record 6 of Set 8 | nishihara
# Processing Record 7 of Set 8 | shache
# Processing Record 8 of Set 8 | aketi
# Processing Record 9 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 8 | adre
# Processing Record 11 of Set 8 | grand baie
# Processing Record 12 of Set 8 | istok
# Processing Record 13 of Set 8 | kodarma
# Processing Record 14 of Set 8 | tando jam
# Processing Record 15 of Set 8 | sorland
# Processing Record 16 of Set 8 | kavieng
# Processing Record 17 of Set 8 | nagorsk
# Processing Record 18 of Set 8 | tuatapere
# Processing Record 19 of Set 8 | bahia de caraquez
# Processing Record 20 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | phan thiet
# Processing Record 22 of Set 8 | danilov
# Processing Record 23 of Set 8 | avera
# Processing Record 24 of Set 8 | onda
# Processing Record 25 of Set 8 | price
# Processing Record 26 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 27 of Set 8 | faanui
# Processing Record 28 of Set 8 | sivaki
# Processing Record 29 of Set 8 | springbok
# Processing Record 30 of Set 8 | cravo norte
# Processing Record 31 of Set 8 | brokopondo
# Processing Record 32 of Set 8 | alofi
# Processing Record 33 of Set 8 | saint anthony
# Processing Record 34 of Set 8 | shaunavon
# Processing Record 35 of Set 8 | natal
# Processing Record 36 of Set 8 | trudarmeyskiy
# Processing Record 37 of Set 8 | carballo
# Processing Record 38 of Set 8 | saint-georges
# Processing Record 39 of Set 8 | tiksi
# Processing Record 40 of Set 8 | mumford
# Processing Record 41 of Set 8 | san ignacio
# Processing Record 42 of Set 8 | tekeli
# Processing Record 43 of Set 8 | batemans bay
# Processing Record 44 of Set 8 | boppard
# Processing Record 45 of Set 8 | vysokogornyy
# Processing Record 46 of Set 8 | san jose iturbide
# Processing Record 47 of Set 8 | axim
# Processing Record 48 of Set 8 | naze
# Processing Record 49 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 8 | cayenne
# Processing Record 1 of Set 9 | bafoulabe
# Processing Record 2 of Set 9 | feijo
# Processing Record 3 of Set 9 | grindavik
# Processing Record 4 of Set 9 | gorom-gorom
# Processing Record 5 of Set 9 | bheramara
# Processing Record 6 of Set 9 | souillac
# Processing Record 7 of Set 9 | zhangye
# Processing Record 8 of Set 9 | altamont
# Processing Record 9 of Set 9 | hayden
# Processing Record 10 of Set 9 | vila velha
# Processing Record 11 of Set 9 | san juan
# Processing Record 12 of Set 9 | palmer
# Processing Record 13 of Set 9 | xiamen
# Processing Record 14 of Set 9 | jega
# Processing Record 15 of Set 9 | ust-ishim
# Processing Record 16 of Set 9 | nagtipunan
# Processing Record 17 of Set 9 | camacha
# Processing Record 18 of Set 9 | porto tolle
# Processing Record 19 of Set 9 | ocala
# Processing Record 20 of Set 9 | khani
# Processing Record 21 of Set 9 | rawson
# Processing Record 22 of Set 9 | baghdad
# Processing Record 23 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 9 | svetlyy
# Processing Record 25 of Set 9 | tahta
# Processing Record 26 of Set 9 | belyy
# Processing Record 27 of Set 9 | nabire
# Processing Record 28 of Set 9 | nioki
# Processing Record 29 of Set 9 | airai
# Processing Record 30 of Set 9 | codrington
# Processing Record 31 of Set 9 | ambon
# Processing Record 32 of Set 9 | hofn
# Processing Record 33 of Set 9 | santa fe
# Processing Record 34 of Set 9 | trincomalee
# Processing Record 35 of Set 9 | east hemet
# Processing Record 36 of Set 9 | mandalgovi
# Processing Record 37 of Set 9 | hualmay
# Processing Record 38 of Set 9 | teguldet
# Processing Record 39 of Set 9 | contamana
# Processing Record 40 of Set 9 | yulara
# Processing Record 41 of Set 9 | kulhudhuffushi
# Processing Record 42 of Set 9 | shemonaikha
# Processing Record 43 of Set 9 | kathu
# Processing Record 44 of Set 9 | krasnovishersk
# Processing Record 45 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 46 of Set 9 | bukama
# Processing Record 47 of Set 9 | malakal
# Processing Record 48 of Set 9 | vilyuysk
# Processing Record 49 of Set 9 | ngunguru
# Processing Record 50 of Set 9 | huarmey
# Processing Record 1 of Set 10 | umm lajj
# Processing Record 2 of Set 10 | batagay
# Processing Record 3 of Set 10 | chihuahua
# Processing Record 4 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 10 | lagoa
# Processing Record 6 of Set 10 | karratha
# Processing Record 7 of Set 10 | rosita
# Processing Record 8 of Set 10 | cooma
# Processing Record 9 of Set 10 | manggar
# Processing Record 10 of Set 10 | panalingaan
# Processing Record 11 of Set 10 | ruteng
# Processing Record 12 of Set 10 | sicamous
# Processing Record 13 of Set 10 | oktyabrskiy
# Processing Record 14 of Set 10 | salvador
# Processing Record 15 of Set 10 | caborca
# Processing Record 16 of Set 10 | port keats
# Processing Record 17 of Set 10 | kahului
# Processing Record 18 of Set 10 | zouxian
# City not found. Skipping...
# Processing Record 19 of Set 10 | itacarambi
# Processing Record 20 of Set 10 | micheweni
# Processing Record 21 of Set 10 | northam
# Processing Record 22 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 10 | kautokeino
# Processing Record 24 of Set 10 | pailon
# Processing Record 25 of Set 10 | tromso
# Processing Record 26 of Set 10 | ringkobing
# Processing Record 27 of Set 10 | iwata
# Processing Record 28 of Set 10 | wuchi
# Processing Record 29 of Set 10 | kagoro
# Processing Record 30 of Set 10 | san cristobal
# Processing Record 31 of Set 10 | minab
# Processing Record 32 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 10 | yar-sale
# Processing Record 34 of Set 10 | lasa
# Processing Record 35 of Set 10 | fairbanks
# Processing Record 36 of Set 10 | qaqortoq
# Processing Record 37 of Set 10 | mo i rana
# Processing Record 38 of Set 10 | jeremie
# Processing Record 39 of Set 10 | wellingborough
# Processing Record 40 of Set 10 | chom bung
# City not found. Skipping...
# Processing Record 41 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 42 of Set 10 | coralville
# Processing Record 43 of Set 10 | pontal do parana
# Processing Record 44 of Set 10 | te anau
# Processing Record 45 of Set 10 | shingu
# Processing Record 46 of Set 10 | wajima
# Processing Record 47 of Set 10 | bure
# Processing Record 48 of Set 10 | qui nhon
# Processing Record 49 of Set 10 | murgab
# Processing Record 50 of Set 10 | blagoyevo
# Processing Record 1 of Set 11 | khvoynaya
# Processing Record 2 of Set 11 | palmeira
# Processing Record 3 of Set 11 | caravelas
# Processing Record 4 of Set 11 | sakakah
# Processing Record 5 of Set 11 | puerto escondido
# Processing Record 6 of Set 11 | meulaboh
# Processing Record 7 of Set 11 | colac
# Processing Record 8 of Set 11 | buraydah
# Processing Record 9 of Set 11 | paamiut
# Processing Record 10 of Set 11 | zaranj
# Processing Record 11 of Set 11 | verkhnevilyuysk
# Processing Record 12 of Set 11 | urgut
# Processing Record 13 of Set 11 | marshall
# Processing Record 14 of Set 11 | petropavl
# Processing Record 15 of Set 11 | akureyri
# Processing Record 16 of Set 11 | puri
# Processing Record 17 of Set 11 | roma
# Processing Record 18 of Set 11 | beidao
# Processing Record 19 of Set 11 | vila franca do campo
# Processing Record 20 of Set 11 | porto novo
# Processing Record 21 of Set 11 | ambilobe
# Processing Record 22 of Set 11 | kamenka
# Processing Record 23 of Set 11 | chifeng
# Processing Record 24 of Set 11 | huanren
# Processing Record 25 of Set 11 | honiara
# Processing Record 26 of Set 11 | khasan
# Processing Record 27 of Set 11 | sangerhausen
# Processing Record 28 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 11 | songadh
# Processing Record 30 of Set 11 | opava
# Processing Record 31 of Set 11 | kalmunai
# Processing Record 32 of Set 11 | barth
# Processing Record 33 of Set 11 | ejido
# Processing Record 34 of Set 11 | eastbourne
# Processing Record 35 of Set 11 | husavik
# Processing Record 36 of Set 11 | brownsville
# Processing Record 37 of Set 11 | ayagoz
# Processing Record 38 of Set 11 | luau
# Processing Record 39 of Set 11 | okakarara
# Processing Record 40 of Set 11 | baykit
# Processing Record 41 of Set 11 | broken hill
# Processing Record 42 of Set 11 | termiz
# Processing Record 43 of Set 11 | takoradi
# Processing Record 44 of Set 11 | halifax
# Processing Record 45 of Set 11 | udachnyy
# Processing Record 46 of Set 11 | rapid valley
# Processing Record 47 of Set 11 | buarcos
# Processing Record 48 of Set 11 | scottsbluff
# Processing Record 49 of Set 11 | quatre cocos
# Processing Record 50 of Set 11 | bahir dar
# Processing Record 1 of Set 12 | arlit
# Processing Record 2 of Set 12 | arica
# Processing Record 3 of Set 12 | methoni
# Processing Record 4 of Set 12 | beringovskiy
# Processing Record 5 of Set 12 | puerto carreno
# Processing Record 6 of Set 12 | khandyga
# Processing Record 7 of Set 12 | dimbokro
# Processing Record 8 of Set 12 | puerto maldonado
# Processing Record 9 of Set 12 | bolshaya murta
# City not found. Skipping...
# Processing Record 10 of Set 12 | benguela
# Processing Record 11 of Set 12 | maralal
# Processing Record 12 of Set 12 | emerald
# Processing Record 13 of Set 12 | sansai
# City not found. Skipping...
# Processing Record 14 of Set 12 | mount isa
# Processing Record 15 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 16 of Set 12 | mastic beach
# Processing Record 17 of Set 12 | ilovlya
# Processing Record 18 of Set 12 | todos santos
# Processing Record 19 of Set 12 | berlevag
# Processing Record 20 of Set 12 | kichera
# Processing Record 21 of Set 12 | yumen
# Processing Record 22 of Set 12 | dunedin
# Processing Record 23 of Set 12 | maragogi
# Processing Record 24 of Set 12 | weatherford
# Processing Record 25 of Set 12 | springs
# Processing Record 26 of Set 12 | mossendjo
# Processing Record 27 of Set 12 | pedernales
# Processing Record 28 of Set 12 | mookane
# Processing Record 29 of Set 12 | kouroussa
# Processing Record 30 of Set 12 | madimba
# Processing Record 31 of Set 12 | ugoofaaru
# Processing Record 32 of Set 12 | jaisalmer
# Processing Record 33 of Set 12 | borlange
# City not found. Skipping...
# Processing Record 34 of Set 12 | cagamutan
# City not found. Skipping...
# Processing Record 35 of Set 12 | kochinda
# Processing Record 36 of Set 12 | mocuba
# Processing Record 37 of Set 12 | oistins
# Processing Record 38 of Set 12 | nelson bay
# Processing Record 39 of Set 12 | nioro
# Processing Record 40 of Set 12 | omboue
# Processing Record 41 of Set 12 | bernardino de campos
# Processing Record 42 of Set 12 | kota bahru
# Processing Record 43 of Set 12 | dicabisagan
# Processing Record 44 of Set 12 | preobrazheniye
# Processing Record 45 of Set 12 | sibolga
# Processing Record 46 of Set 12 | manalongon
# Processing Record 47 of Set 12 | tilichiki
# Processing Record 48 of Set 12 | sept-iles
# Processing Record 49 of Set 12 | atar
# Processing Record 50 of Set 12 | wakkanai
# Processing Record 1 of Set 13 | shahr-e babak
# Processing Record 2 of Set 13 | laguna
# Processing Record 3 of Set 13 | kincardine
# Processing Record 4 of Set 13 | nkhata bay
# Processing Record 5 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 6 of Set 13 | coihaique
# Processing Record 7 of Set 13 | leningradskiy
# Processing Record 8 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 13 | beyneu
# Processing Record 10 of Set 13 | chippewa falls
# Processing Record 11 of Set 13 | dulce nombre de culmi
# Processing Record 12 of Set 13 | gasa
# Processing Record 13 of Set 13 | moose factory
# Processing Record 14 of Set 13 | richards bay
# Processing Record 15 of Set 13 | amapa
# Processing Record 16 of Set 13 | san quintin
# Processing Record 17 of Set 13 | sorgun
# Processing Record 18 of Set 13 | lebanon
# Processing Record 19 of Set 13 | mbandaka
# Processing Record 20 of Set 13 | opuwo
# Processing Record 21 of Set 13 | jizan
# Processing Record 22 of Set 13 | san andres
# Processing Record 23 of Set 13 | walvis bay
# Processing Record 24 of Set 13 | north bend
# Processing Record 25 of Set 13 | jiblah
# Processing Record 26 of Set 13 | bolotnoye
# Processing Record 27 of Set 13 | kerman
# Processing Record 28 of Set 13 | chabahar
# Processing Record 29 of Set 13 | singaraja
# Processing Record 30 of Set 13 | otradnoye
# Processing Record 31 of Set 13 | palasa
# Processing Record 32 of Set 13 | lekoni
# Processing Record 33 of Set 13 | dharchula
# Processing Record 34 of Set 13 | port hedland
# Processing Record 35 of Set 13 | makakilo city
# Processing Record 36 of Set 13 | ulety
# Processing Record 37 of Set 13 | sao gabriel da cachoeira
# Processing Record 38 of Set 13 | bundaberg
# Processing Record 39 of Set 13 | rabaul
# Processing Record 40 of Set 13 | kupang
# Processing Record 41 of Set 13 | saint-joseph
# Processing Record 42 of Set 13 | esmeraldas
# Processing Record 43 of Set 13 | alice springs
# Processing Record 44 of Set 13 | los andes
# Processing Record 45 of Set 13 | tamiahua
# Processing Record 46 of Set 13 | lima
# Processing Record 47 of Set 13 | parana
# Processing Record 48 of Set 13 | milkovo
# Processing Record 49 of Set 13 | namatanai
# Processing Record 50 of Set 13 | darmanesti
# Processing Record 1 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 2 of Set 14 | pucallpa
# Processing Record 3 of Set 14 | vestmanna
# Processing Record 4 of Set 14 | gayeri
# Processing Record 5 of Set 14 | seymchan
# Processing Record 6 of Set 14 | curitibanos
# Processing Record 7 of Set 14 | oksfjord
# Processing Record 8 of Set 14 | mangochi
# Processing Record 9 of Set 14 | champasak
# Processing Record 10 of Set 14 | chicama
# Processing Record 11 of Set 14 | kalmar
# Processing Record 12 of Set 14 | ishigaki
# Processing Record 13 of Set 14 | merauke
# Processing Record 14 of Set 14 | boca do acre
# Processing Record 15 of Set 14 | salair
# Processing Record 16 of Set 14 | neuquen
# Processing Record 17 of Set 14 | ola
# Processing Record 18 of Set 14 | mooi river
# City not found. Skipping...
# Processing Record 19 of Set 14 | cururupu
# Processing Record 20 of Set 14 | taltal
# Processing Record 21 of Set 14 | aykhal
# Processing Record 22 of Set 14 | eureka
# Processing Record 23 of Set 14 | itamaraju
# Processing Record 24 of Set 14 | atherton
# Processing Record 25 of Set 14 | jasper
# Processing Record 26 of Set 14 | borogontsy
# Processing Record 27 of Set 14 | viljoenskroon
# Processing Record 28 of Set 14 | nogales
# Processing Record 29 of Set 14 | hovd
# Processing Record 30 of Set 14 | ravar
# Processing Record 31 of Set 14 | arman
# Processing Record 32 of Set 14 | olinda
# Processing Record 33 of Set 14 | anadyr
# Processing Record 34 of Set 14 | gwalior
# Processing Record 35 of Set 14 | sivas
# Processing Record 36 of Set 14 | birao
# Processing Record 37 of Set 14 | sampit
# Processing Record 38 of Set 14 | tsaratanana
# Processing Record 39 of Set 14 | benton harbor
# Processing Record 40 of Set 14 | iralaya
# Processing Record 41 of Set 14 | worland
# Processing Record 42 of Set 14 | kattivakkam
# Processing Record 43 of Set 14 | moroni
# Processing Record 44 of Set 14 | hokitika
# Processing Record 45 of Set 14 | terrace
# Processing Record 46 of Set 14 | homer
# Processing Record 47 of Set 14 | arivonimamo
# Processing Record 48 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 49 of Set 14 | rosarito
# Processing Record 50 of Set 14 | changde
# Processing Record 1 of Set 15 | mount darwin
# Processing Record 2 of Set 15 | pauini
# Processing Record 3 of Set 15 | druzhnaya gorka
# Processing Record 4 of Set 15 | klyuchi
# Processing Record 5 of Set 15 | mananara
# Processing Record 6 of Set 15 | najran
# Processing Record 7 of Set 15 | hun
# Processing Record 8 of Set 15 | murakami
# Processing Record 9 of Set 15 | ornskoldsvik
# Processing Record 10 of Set 15 | boyuibe
# Processing Record 11 of Set 15 | mokhsogollokh
# Processing Record 12 of Set 15 | chodavaram
# Processing Record 13 of Set 15 | toora-khem
# Processing Record 14 of Set 15 | atasu
# Processing Record 15 of Set 15 | urengoy
# Processing Record 16 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 15 | yuci
# Processing Record 18 of Set 15 | adrar
# Processing Record 19 of Set 15 | galich
# Processing Record 20 of Set 15 | bela
# Processing Record 21 of Set 15 | lazarev
# Processing Record 22 of Set 15 | beaverlodge
# Processing Record 23 of Set 15 | mareeba
# Processing Record 24 of Set 15 | warmbad
# Processing Record 25 of Set 15 | impfondo
# Processing Record 26 of Set 15 | morgan city
# Processing Record 27 of Set 15 | soyo
# Processing Record 28 of Set 15 | nizhniy kuranakh
# Processing Record 29 of Set 15 | chipinge
# Processing Record 30 of Set 15 | moerai
# Processing Record 31 of Set 15 | panzhihua
# Processing Record 32 of Set 15 | tura
# Processing Record 33 of Set 15 | beloha
# Processing Record 34 of Set 15 | ji-parana
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Nanortalik      GL  60.14  -45.24     31.10        92         100
# 1      Birjand      IR  32.87   59.22     50.00        19           0
# 2        Bluff      NZ -46.60  168.33     53.01        55          21
# 3  New Norfolk      AU -42.78  147.06     64.00        47          20
# 4    Busselton      AU -33.65  115.33     64.00        90          46
#
#    Wind Speed Current Description
# 0        8.39     overcast clouds
# 1        6.93           clear sky
# 2       11.01          few clouds
# 3        8.05          few clouds
# 4        5.37    scattered clouds

# %%
city_data_df.loc[city_data_df["City"]=='Ushuaia']
# Out:
#        City Country   Lat   Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 40  Ushuaia      AR -54.8 -68.3      57.2        54          40       12.75
#
#    Current Description
# 40    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-eeb728395b0e> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#       5
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
